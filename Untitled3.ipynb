# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Hello Capstone Project Course

# %%
# %cd /content/drive/MyDrive/Ibm_data_science
# !git init
# !git remote add origin https://hieuphanuit:Hieuiskingpro1998@github.com/hieuphanuit/data-science-ibm-capstone.git
# Out:
# /content/drive/MyDrive/Ibm_data_science
# Initialized empty Git repository in /content/drive/MyDrive/Ibm_data_science/.git/

# %%
# !git add .
