# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Hello Capstone Project Course

# %%
# Out:
# /content/drive/MyDrive/Ibm_data_science
# Initialized empty Git repository in /content/drive/MyDrive/Ibm_data_science/.git/

# %%
# !git add .
# !git commit -m "first commit"
# !git branch -M master
# !git push -u origin master
# Out:
# [master (root-commit) 4bfc63c] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 Untitled3.ipynb
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 1.05 KiB | 359.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/hieuphanuit/data-science-ibm-capstone.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
